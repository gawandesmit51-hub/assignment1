# %% [markdown]
# #Multiplication Table:
# #Print the multiplication table of a given number (e.g., for 5).

# %%
n=float(input("Enter the number"))
for i in range(1,11):
    print(i*n)
# Out:
# Enter the number 5.747
# 5.747
# 11.494
# 17.241
# 22.988
# 28.735
# 34.482
# 40.229
# 45.976
# 51.723
# 57.47
